# %% [markdown]
# <a href="https://colab.research.google.com/github/Nishantthakurrr/Time-Series-Analysis-S-P-500-/blob/main/S%26P_500_GOOG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Questions:-
# 1. How to read a CSV file with Pandas?
# 2. How does stock price change on different days?
# 3. What is the stock's Moving Average?

# %%
# The first step is to load the csv file in the colab through Pandas

t= pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vTjXECBaVxzxl3xPQxU25h-Cve6JiLPv_TThrlY9j1J2R6T61xvKZqX3Nf6Reh19LfkpJqYcgVnwEyr/pub?gid=1681697291&single=true&output=csv")

# %%
t
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2023-06-29  120.089996  120.910004  119.209999  120.010002  119.873589
# 1    2023-06-30  121.099998  122.029999  120.879997  120.970001  120.832497
# 2    2023-07-03  120.320000  121.019997  119.705002  120.559998  120.422958
# 3    2023-07-05  120.059998  123.370003  120.059998  122.629997  122.490608
# 4    2023-07-06  120.639999  121.150002  119.250000  120.930000  120.792542
# ..          ...         ...         ...         ...         ...         ...
# 247  2024-06-24  181.279999  182.080002  180.229996  180.789993  180.789993
# 248  2024-06-25  181.145004  185.750000  181.104996  185.580002  185.580002
# 249  2024-06-26  184.199997  185.929993  183.990005  185.369995  185.369995
# 250  2024-06-27  185.645004  187.500000  185.449997  186.860001  186.860001
# 251  2024-06-28  185.720001  186.580002  183.324997  183.419998  183.419998
#
#        Volume
# 0    18517500
# 1    23865800
# ...

# %%
t.describe() # you can see the max, min values and volume of the stock price
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   144.638778  146.132143  143.416048  144.848611  144.695355
# std     16.756381   16.882240   16.701079   16.883169   16.888103
# min    116.760002  118.224998  115.830002  116.870003  116.737160
# 25%    132.914997  134.100003  131.462498  133.182499  133.031120
# 50%    139.524994  140.675003  138.190002  139.529999  139.371399
# 75%    152.992496  155.079994  152.102005  153.827495  153.652649
# max    185.720001  187.500000  185.449997  186.860001  186.860001
#
#              Volume
# count  2.520000e+02
# mean   2.168560e+07
# std    8.374175e+06
# min    8.828600e+06
# 25%    1.693515e+07
# 50%    1.922505e+07
# 75%    2.318745e+07
# max    5.972800e+07

# %%
t.columns # you can check the columns presented in the data set
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
t.shape # This is the shape of the data set consisting 252 rows followed by 7 columns.
# Out:
# (252, 7)

# %%
t.isnull().sum() # Checking the null values in the dataset.
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
t.dtypes # Checking the data type of every Column
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
pd.to_datetime(t['Date']) # Changing the data type of the column for smooth Graphical Representation
# Out:
# 0     2023-06-29
# 1     2023-06-30
# 2     2023-07-03
# 3     2023-07-05
# 4     2023-07-06
#          ...
# 247   2024-06-24
# 248   2024-06-25
# 249   2024-06-26
# 250   2024-06-27
# 251   2024-06-28
# Name: Date, Length: 252, dtype: datetime64[ns]

# %%
# Change in price according to days passed.

plt.figure(figsize=(12, 6)) # Define the figure size you want
plt.plot(t['Date'], t['Close'], label='Closing Price')

# Customize the plot
plt.title('Stock Price')
plt.xlabel('Date')
plt.ylabel('Close')
plt.legend()
plt.grid(False) # Used for the griding effeect in the chart

# Display the plot
plt.show()

# %%
# Change in volume on each date

plt.figure(figsize=(110, 16))
plt.bar(t["Date"], t['Volume'], label='Volume')

# Customize the plot
plt.title("Stock Volume")
plt.xlabel('Date')
plt.ylabel('Volume')
plt.legend()
plt.grid(True)

# Display the plot
plt.show()

# %%
# As you can see I have calculated the MA by using the first 10 Close price data and so on

plt.figure(figsize=(12, 6)) # Define the figure size you want
plt.plot(t['Date'], t['Close'], label='Closing Price')
plt.plot(t['Date'], t['Close'].rolling(window=10).mean(), label='Moving Average', color="orange") # Used rolling function

# Customize the plot
plt.title('Stock Price')
plt.xlabel('Date')
plt.ylabel('Close')
plt.legend()
plt.grid(False) # Used for the griding effeect in the chart

# Display the plot
plt.show()
